# %%
           
# Introduction to the Ocean survival game
print(
f"""
{'-' * 40}
Hi there!!!! 
You just woke up and find yourself in the middle of the ocean in a small speed boat. 
You were a part of the crew of a large ship. 
You can’t understand why did you end up like this as probably you had a lot of drinks at a party on your ship last night.\U0001F60B\U0001F60B\U0001F60B\U0001F60B

As you start looking around, suddenly you see your ship on the west. 
However, it seems it is going away from you. You try starting your boat but find out that you do not have enough fuel to reach there.

Looking back, you see an unknown ISLAND. It looks near. 
With the limited fuel you can definitely reach there with your boat. 
You may find more fuel from the locals or contact your ship by some means. 
BUT MY FRIEND, it is an unknown island and there could be many UNKNOWN RISKS.
\U0001F922 \U0001F922 \U0001F922

{'-' * 40}
""")

#dynamically applying the user input.
name = input(" Ooh,really sorry. I forgot your name. EVEN I WAS DRUNK! Please enter your name\U0001F60B \t")
print("  ")
print(" Hey "  + name +  ". Let's start the game! \U0001F3C3")
print("  ")
print(" You need to select the options further very MINDFULLY, else you won't SURVIVE \U0001F628.")

#defines the list of rooms in the game with descriptions.
#stage_1 provides the major two options and then the game takes you further based on your choice.
#directions is the paths to move forward in the game after you select the major options.
stage_1 = ["Island", "Ship"]
directions = ["Swim towards ship","Wait for evacuation","fight_back","bribe"]


#allows the user to display dead option and defines it more elaborately
def dead():
    print(" You're dead! Please try again \n ")
    
       
##allows the user to define that they have lost in the game and can try again
def you_lost():
    print(' You did not survive.\n')
    input(prompt = ' To play again please press enter \t')
    response = ''

#allows the user to fail the game 
def fail():
    print(f"You failed the game.Good bye {name} \n")

#allows the user to know he/she won the game   
def won():
    print(' ### YOU WON...!!!!!###\U0001F60A \U0001F60A \U0001F60A')
    
 
#allows the user to know that they are stuck in the game and lost the game
def stuck():
    print(' You are one of them. They will keep you for everrrrr!!! Hope you enjoy. \n')
    print(' Good bye..!!')
    you_lost()
  
#allows the use to select an option and move further by dying or failing the game
def fight_back():
    print(' You rush to your boat and all you can find is a stick. You are scared.\n Now you decide to…\n 1.Fight using the stick \n 2.Give up and do nothing \n')
    response = input("> ")
    #printing and providing the selected options and move forward by conditional statement
    if response == '1':
        print(
f""" 
You are brave {name}. 
But not a hero of a Hollywood movie.\U0001F3A5 \U0001F3A5
Even before you can reach them, they shot you down with arrows.
""")
        dead() or you_lost()
    elif response == '2':
        print(
""" 
They killed you!  
You failed the game! 
""")
        fail()

#it takes you to the option of bribe. And again allows you to start the game
def bribe():
    print(' You try to bribe them with some chocolates you find in your pocket.They ate it.haahah. \n But they were dark chocolates \U0001F440 and they did not like it. \n They thought you were poisoning them. \n They killed you on the spot! Bad luck!\n ')
    dead() or you_lost()
    
#allows you to move forward with the options in the game by conditional statement    
def to_entertain():
    print(' So, you decide to…\n 1.Dance \n 2.Cry \n')
    response = input("> ")
    if response == 'Dance'.ca or response == '1':
        print(' Wow! You are a great dancer! They are impressed! \n They made you dance in front of entire tribal community for a whole night.\n They not only set you free but they offered to drop you back at your ship.\n Congratulations!\n You survived!\n ')
        won()
    elif response == 'Cry' or response == '2':
        print(f" You are a drama queen {name} \U0001F3A5 . \n Seeing you cry like a baby they felt pity on you. They want to adopt you.. \U0001F440 \U0001F440 \U0001F440 \n So, they made you one of them and now you are a part of their tribe. They won’t let you go. \n Well, you survived but stuck there forever! \n Game to be continued ……\n ")
        you_lost()
    else:
        print(' Invalid entry.')

#it takes you to the option and declares the game        
def swim_towards_ship():
    print(' But looks like someone is there around you.\n Its SHARK!!!! \U0001F440 \U0001F440 \U0001F440 You are now meal of the shark.\U0001F922 \n You are dead! Bad choice!')
    you_lost()


# Start of the while loop
#allows the user to enter a command and takes the appropriate action.    

response = ''
while response not in stage_1:
    response = input(" 1.Lets go to the island and find out other means to go back. \n 2.Lets use the limited fuel and try reaching near to the ship as much as possible \n ")
    
    if response == '1':
        print("  ")
        print(
        f"""
{'-' * 40} 
You start the boat and start heading towards the island.\U0001F3C3
    
You reached!
Such a beautiful island!!!
    
But do you hear some shouts and you see bunch of people coming towards you...?? 
They are local tribes!
    
Wait! They have bows and arrows and they are not looking friendly.\U0001F628 \U0001F628
They started shooting arrows at you as you are an outsider.
    
So, you decide to…
    
1.Fight back with whatever you can find
    
2.Try to bribe them with whatever you have
    
3.Entertain them and confuse them.
    
{'-' * 40}
""")
        
        response = input("> ")
        #start of the nested condition
        if  response == '1':
            print("  ")
            print(f"You are brave {name}.")
            fight_back()
        elif response == '2':
            print("  ")
            print(f"You are smart {name} ")
            bribe()
        else:
            print("  ")
            print(f"You are a born entertainer {name}. ")
            to_entertain()   
        #End of the nested condition
        
    elif response == '2':
        print(
f""" 
{'*' * 40}
    
Okay...Now start your boat and start heading towards your ship.
Your destination is almost there. 
    
But, oh noo!\U0001F628 You ran out of fuel!\U0001F628
    
Your boat will stop in a while but your ship is slowly going away from you.
Now, you decide to… 
    
1.Jump out of your boat and start swimming towards your ship 
    
2.Wave and shout loud hoping somebody will hear you or see you from the ship and you will be rescued.
    
{'*' * 40}
""")
        response = input(">")
        #start of the nested condition
        print("  ")
        if response == '1':
            print("  ")
            print(f"So now you started swimming \U0001F917...You are a good swimmer, doing good !! {name}!!")
            swim_towards_ship()
        elif response =='2':
            print("  ")
            print(' Oh my goshh!!!\U0001F917 \n You are Shouting and waving, you are draining all your energy.\n But, looks like your ship just stopped and you see a rescue boat coming towards you.\n Hurrey! You survived!\U0001F340')
            won()
        else:
            print("  ")
            print(' Invalid Entry')
         #End of the nested condition
         
    #last else condition      
    else: 
        print(f" I didn't understand that {name}. \n ")
 
#End of the game
